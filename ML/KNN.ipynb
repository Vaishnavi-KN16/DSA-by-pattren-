# %%
import sklearn 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
dataset = load_iris()
x=dataset.data
y=dataset.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# size of the train and test data
print("Size of training data:", x_train.shape,y_train.shape)
print("Size of test data:", x_test.shape,y_test.shape)
# print iris target names
print( " iris target names " ,dataset.target_names)
Classifier= KNeighborsClassifier( n_neighbors=1)

Classifier.fit(x_train,y_train)
y_pred=Classifier.predict(x_test)
for r in range( 0,len(x_test)):
    print( " Sample :",str(x_test[r])," Actual class :",str( y_test[r]),"predicted class :",str(y_pred[r]))
print( " Accuracy of the model is : ",Classifier.score(x_test,y_test))
print( " Confusion matrix : " ,confusion_matrix(y_test,y_pred))
print( " Classification report : " ,classification_report(y_test,y_pred))
# Out:
# Size of training data: (120, 4) (120,)
# Size of test data: (30, 4) (30,)
#  iris target names  ['setosa' 'versicolor' 'virginica']
#  Sample : [6.1 2.8 4.7 1.2]  Actual class : 1 predicted class : 1
#  Sample : [5.7 3.8 1.7 0.3]  Actual class : 0 predicted class : 0
#  Sample : [7.7 2.6 6.9 2.3]  Actual class : 2 predicted class : 2
#  Sample : [6.  2.9 4.5 1.5]  Actual class : 1 predicted class : 1
#  Sample : [6.8 2.8 4.8 1.4]  Actual class : 1 predicted class : 1
#  Sample : [5.4 3.4 1.5 0.4]  Actual class : 0 predicted class : 0
#  Sample : [5.6 2.9 3.6 1.3]  Actual class : 1 predicted class : 1
#  Sample : [6.9 3.1 5.1 2.3]  Actual class : 2 predicted class : 2
#  Sample : [6.2 2.2 4.5 1.5]  Actual class : 1 predicted class : 1
#  Sample : [5.8 2.7 3.9 1.2]  Actual class : 1 predicted class : 1
#  Sample : [6.5 3.2 5.1 2. ]  Actual class : 2 predicted class : 2
#  Sample : [4.8 3.  1.4 0.1]  Actual class : 0 predicted class : 0
#  Sample : [5.5 3.5 1.3 0.2]  Actual class : 0 predicted class : 0
#  Sample : [4.9 3.1 1.5 0.1]  Actual class : 0 predicted class : 0
#  Sample : [5.1 3.8 1.5 0.3]  Actual class : 0 predicted class : 0
#  Sample : [6.3 3.3 4.7 1.6]  Actual class : 1 predicted class : 1
#  Sample : [6.5 3.  5.8 2.2]  Actual class : 2 predicted class : 2
#  Sample : [5.6 2.5 3.9 1.1]  Actual class : 1 predicted class : 1
#  Sample : [5.7 2.8 4.5 1.3]  Actual class : 1 predicted class : 1
#  Sample : [6.4 2.8 5.6 2.2]  Actual class : 2 predicted class : 2
#  Sample : [4.7 3.2 1.6 0.2]  Actual class : 0 predicted class : 0
#  Sample : [6.1 3.  4.9 1.8]  Actual class : 2 predicted class : 2
#  Sample : [5.  3.4 1.6 0.4]  Actual class : 0 predicted class : 0
#  Sample : [6.4 2.8 5.6 2.1]  Actual class : 2 predicted class : 2
#  Sample : [7.9 3.8 6.4 2. ]  Actual class : 2 predicted class : 2
#  Sample : [6.7 3.  5.2 2.3]  Actual class : 2 predicted class : 2
#  Sample : [6.7 2.5 5.8 1.8]  Actual class : 2 predicted class : 2
#  Sample : [6.8 3.2 5.9 2.3]  Actual class : 2 predicted class : 2
#  Sample : [4.8 3.  1.4 0.3]  Actual class : 0 predicted class : 0
#  Sample : [4.8 3.1 1.6 0.2]  Actual class : 0 predicted class : 0
#  Accuracy of the model is :  1.0
#  Confusion matrix :  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#  Classification report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
import sklearn
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
dataset = load_iris()
x=dataset.data
y=dataset.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=42)
gnb=GaussianNB()
classifier=gnb.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
print( " Accuracy metrics",classification_report(y_test,y_pred))
print( " Accuracy of the model ",accuracy_score(y_test,y_pred))
print( " confusion matrix",confusion_matrix(y_test,y_pred))
# Out:
#  Accuracy metrics               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         3
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15
#
#  Accuracy of the model  1.0
#  confusion matrix [[6 0 0]
#  [0 6 0]
#  [0 0 3]]

# %%
# on a random data set 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
